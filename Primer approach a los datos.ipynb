# %% [markdown]
# ***En este notebook se hizo un pequeño análisis preliminar de los datos recolectados de distintas fuentes, se verificó si existen nulos, los tipos de datos de las columnas, y una pequeña descripcion estadística de las columnas con tipos de datos numéricos***

# %%
import pandas as pd
from simpledbf import Dbf5

# %% [markdown]
# ***Primero vamos a leer cada csv y a hacer una pequeña exploracion. En cada celda voy a poner un comentario diciendo lo que encontré***

# %%
ElectricCarDataClean=pd.read_csv('Datasets/ElectricCarData_Clean.csv')
ElectricCarDataClean
# Out:
#            Brand                            Model  AccelSec  TopSpeed_KmH  \
# 0         Tesla     Model 3 Long Range Dual Motor       4.6           233
# 1    Volkswagen                         ID.3 Pure      10.0           160
# 2      Polestar                                 2       4.7           210
# 3           BMW                              iX3        6.8           180
# 4         Honda                                e        9.5           145
# ..           ...                              ...       ...           ...
# 98       Nissan                       Ariya 63kWh       7.5           160
# 99         Audi     e-tron S Sportback 55 quattro       4.5           210
# 100      Nissan               Ariya e-4ORCE 63kWh       5.9           200
# 101      Nissan   Ariya e-4ORCE 87kWh Performance       5.1           200
# 102       Byton                 M-Byte 95 kWh 2WD       7.5           190
#
#      Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# ...

# %%
ElectricCarDataClean.isna().sum()
# Out:
# Brand              0
# Model              0
# AccelSec           0
# TopSpeed_KmH       0
# Range_Km           0
# Efficiency_WhKm    0
# FastCharge_KmH     0
# RapidCharge        0
# PowerTrain         0
# PlugType           0
# BodyStyle          0
# Segment            0
# Seats              0
# PriceEuro          0
# dtype: int64

# %%
ElectricCarDataClean.describe()
# Out:
#          AccelSec  TopSpeed_KmH    Range_Km  Efficiency_WhKm       Seats  \
# count  103.000000    103.000000  103.000000       103.000000  103.000000
# mean     7.396117    179.194175  338.786408       189.165049    4.883495
# std      3.017430     43.573030  126.014444        29.566839    0.795834
# min      2.100000    123.000000   95.000000       104.000000    2.000000
# 25%      5.100000    150.000000  250.000000       168.000000    5.000000
# 50%      7.300000    160.000000  340.000000       180.000000    5.000000
# 75%      9.000000    200.000000  400.000000       203.000000    5.000000
# max     22.400000    410.000000  970.000000       273.000000    7.000000
#
#            PriceEuro
# count     103.000000
# mean    55811.563107
# std     34134.665280
# min     20129.000000
# 25%     34429.500000
# 50%     45000.000000
# 75%     65000.000000
# max    215000.000000

# %%
ElectricCarDataClean.dtypes
# Out:
# Brand               object
# Model               object
# AccelSec           float64
# TopSpeed_KmH         int64
# Range_Km             int64
# Efficiency_WhKm      int64
# FastCharge_KmH      object
# RapidCharge         object
# PowerTrain          object
# PlugType            object
# BodyStyle           object
# Segment             object
# Seats                int64
# PriceEuro            int64
# dtype: object

# %% [markdown]
# ***Todo en orden, no hay nulos, hay algunas categoricas que podemos hacerle el dummies, y hay columnas que podemos eliminar***

# %%
ElectricCarDataNorm=pd.read_csv('Datasets/ElectricCarData_Norm.csv')

# %%
ElectricCarDataNorm.isna().sum()
# Out:
# Brand          0
# Model          0
# Accel          0
# TopSpeed       0
# Range          0
# Efficiency     0
# FastCharge     0
# RapidCharge    0
# PowerTrain     0
# PlugType       0
# BodyStyle      0
# Segment        0
# Seats          0
# PriceEuro      0
# dtype: int64

# %%
ElectricCarDataNorm.describe()
# Out:
#             Seats      PriceEuro
# count  103.000000     103.000000
# mean     4.883495   55811.563107
# std      0.795834   34134.665280
# min      2.000000   20129.000000
# 25%      5.000000   34429.500000
# 50%      5.000000   45000.000000
# 75%      5.000000   65000.000000
# max      7.000000  215000.000000

# %%
ElectricCarDataNorm.dtypes
# Out:
# Brand          object
# Model          object
# Accel          object
# TopSpeed       object
# Range          object
# Efficiency     object
# FastCharge     object
# RapidCharge    object
# PowerTrain     object
# PlugType       object
# BodyStyle      object
# Segment        object
# Seats           int64
# PriceEuro       int64
# dtype: object

# %% [markdown]
# ***Todo en orden, no hay nulos, hay algunas categoricas que podemos hacerle el dummies, y hay columnas que podemos eliminar***

# %%
dbf = Dbf5('Datasets/taxi_zones.dbf')

# %%
taxiZones = dbf.to_dataframe()

# %%
taxiZones.isna().sum()
# Out:
# OBJECTID      0
# Shape_Leng    0
# Shape_Area    0
# zone          0
# LocationID    0
# borough       0
# dtype: int64

# %%
taxiZones.describe()
# Out:
#          OBJECTID  Shape_Leng  Shape_Area  LocationID
# count  263.000000  263.000000  263.000000  263.000000
# mean   132.000000    0.094269    0.000402  131.984791
# std     76.065761    0.054594    0.000482   76.073787
# min      1.000000    0.014306    0.000006    1.000000
# 25%     66.500000    0.054722    0.000133   66.500000
# 50%    132.000000    0.084341    0.000268  132.000000
# 75%    197.500000    0.119488    0.000480  197.500000
# max    263.000000    0.433470    0.004866  263.000000

# %%
taxiZones.dtypes
# Out:
# OBJECTID        int64
# Shape_Leng    float64
# Shape_Area    float64
# zone           object
# LocationID      int64
# borough        object
# dtype: object

# %% [markdown]
# ***Todo en orden, no hay nulos, hay algunas categoricas que podemos hacerle el dummies, y hay columnas que podemos eliminar***

# %%
AlternativeFuelChargingStations=pd.read_csv('Datasets/AlternativeFuelChargingStations.csv')
# Out:
# /tmp/ipykernel_8264/2293964561.py:1: DtypeWarning: Columns (6,16,20,31,33,36,39,40,41,43,46,52,53,55,57,58,60,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   AlternativeFuelChargingStations=pd.read_csv('Datasets/AlternativeFuelChargingStations.csv')

# %%
AlternativeFuelChargingStations.isna().sum()
# Out:
# Fuel Type Code                     0
# Station Name                       0
# Street Address                     1
# Intersection Directions        65913
# City                               0
#                                ...
# CNG PSI                        68809
# CNG Vehicle Class              68784
# LNG Vehicle Class              70248
# EV On-Site Renewable Source    70036
# Restricted Access              16971
# Length: 65, dtype: int64

# %%
AlternativeFuelChargingStations.describe()
# Out:
#        Plus4  EV Level1 EVSE Num  EV Level2 EVSE Num  EV DC Fast Count  \
# count    0.0          286.000000        54144.000000       8307.000000
# mean     NaN            3.461538            2.315289          3.576381
# std      NaN            6.548356            3.157387          4.129470
# min      NaN            1.000000            1.000000          1.000000
# 25%      NaN            1.000000            2.000000          1.000000
# 50%      NaN            1.000000            2.000000          2.000000
# 75%      NaN            2.000000            2.000000          4.000000
# max      NaN           51.000000          311.000000         56.000000
#
#            Latitude     Longitude             ID  Federal Agency ID  \
# count  70406.000000  70406.000000   70406.000000         955.000000
# mean      38.929309    -96.061447  148730.326066          13.905759
# std        5.628458     19.545273   54261.672118           6.767439
# ...

# %%
AlternativeFuelChargingStations.dtypes
# Out:
# Fuel Type Code                 object
# Station Name                   object
# Street Address                 object
# Intersection Directions        object
# City                           object
#                                 ...
# CNG PSI                        object
# CNG Vehicle Class              object
# LNG Vehicle Class              object
# EV On-Site Renewable Source    object
# Restricted Access              object
# Length: 65, dtype: object

# %% [markdown]
# ***Aqui si tenemos que verificar los datos, estan desordenados***

# %%
AlternativeFuelVehiclesUS=pd.read_csv('Datasets/AlternativeFuelVehiclesUS.csv')

# %%
AlternativeFuelVehiclesUS.isna().sum()
# Out:
# Category                                0
# Model                                   0
# Model Year                            288
# Manufacturer                            0
# Fuel                                    0
# All-Electric Range                    660
# PHEV Total Range                      839
# Alternative Fuel Economy City         713
# Alternative Fuel Economy Highway      713
# Alternative Fuel Economy Combined     620
# Conventional Fuel Economy City        438
# Conventional Fuel Economy Highway     438
# Conventional Fuel Economy Combined    438
# Transmission Type                     242
# Transmission Make                     757
# Engine Type                           293
# Engine Size                           293
# Engine Cylinder Count                 433
# Number of Passengers                  761
# Heavy-Duty Power System               637
# Notes                                 703
# Drivetrain                            553
# dtype: int64

# %%
AlternativeFuelVehiclesUS.describe()
# Out:
#         Model Year  All-Electric Range  PHEV Total Range  \
# count   594.000000          222.000000         43.000000
# mean   2021.538721          165.927928        450.465116
# std       0.498919          132.992955         93.042578
# min    2021.000000            8.000000        290.000000
# 25%    2021.000000           23.000000        380.000000
# 50%    2022.000000          203.000000        460.000000
# 75%    2022.000000          260.000000        520.000000
# max    2022.000000          520.000000        640.000000
#
#        Alternative Fuel Economy City  Alternative Fuel Economy Highway  \
# count                     169.000000                        169.000000
# mean                       84.585799                         77.591716
# std                        39.430696                         32.735123
# min                        10.000000                         12.000000
# 25%                        71.000000                         66.000000
# ...

# %%
AlternativeFuelVehiclesUS.dtypes
# Out:
# Category                               object
# Model                                  object
# Model Year                            float64
# Manufacturer                           object
# Fuel                                   object
# All-Electric Range                    float64
# PHEV Total Range                      float64
# Alternative Fuel Economy City         float64
# Alternative Fuel Economy Highway      float64
# Alternative Fuel Economy Combined     float64
# Conventional Fuel Economy City        float64
# Conventional Fuel Economy Highway     float64
# Conventional Fuel Economy Combined    float64
# Transmission Type                      object
# Transmission Make                      object
# Engine Type                            object
# Engine Size                            object
# Engine Cylinder Count                 float64
# Number of Passengers                   object
# Heavy-Duty Power System                object
# ...

# %% [markdown]
# ***Aqui hay datos nulos, hay que verificar y eliminar, hay columnas que podemos eliminar y otras que podemos hacerle dummies***

# %%
LightDutyVehicles=pd.read_csv('Datasets/LightDutyVehicles.csv')

# %%
LightDutyVehicles.isna().sum()
# Out:
# Vehicle ID                               0
# Fuel ID                                  0
# Fuel Configuration ID                   35
# Manufacturer ID                          0
# Category ID                              0
# Model                                    0
# Model Year                               0
# Alternative Fuel Economy City         1413
# Alternative Fuel Economy Highway      1503
# Alternative Fuel Economy Combined     2541
# Conventional Fuel Economy City         964
# Conventional Fuel Economy Highway      962
# Conventional Fuel Economy Combined    2245
# Transmission Type                       84
# Engine Type                            797
# Engine Size                            134
# Engine Cylinder Count                  565
# Engine Description                    1037
# Manufacturer                             0
# Manufacturer URL                       164
# Category                                 0
# Fuel Code                                0
# ...

# %%
LightDutyVehicles.describe()
# Out:
#         Vehicle ID      Fuel ID  Fuel Configuration ID  Manufacturer ID  \
# count   3008.00000  3008.000000            2973.000000      3008.000000
# mean    9424.59242    31.003989               4.907164       255.855718
# std     4667.98027    18.311570               3.263154        64.474477
# min        1.00000     3.000000               1.000000       209.000000
# 25%    10280.75000    11.000000               1.000000       215.000000
# 50%    11560.50000    41.000000               5.000000       221.000000
# 75%    12336.25000    45.000000               9.000000       243.000000
# max    13105.00000    57.000000               9.000000       470.000000
#
#        Category ID   Model Year  Alternative Fuel Economy City  \
# count  3008.000000  3008.000000                    1595.000000
# mean     24.988697  2014.493019                      38.439298
# std       6.021677     6.722191                      47.778798
# min       3.000000  1991.000000                       0.000000
# ...

# %%
LightDutyVehicles.dtypes
# Out:
# Vehicle ID                              int64
# Fuel ID                                 int64
# Fuel Configuration ID                 float64
# Manufacturer ID                         int64
# Category ID                             int64
# Model                                  object
# Model Year                              int64
# Alternative Fuel Economy City         float64
# Alternative Fuel Economy Highway      float64
# Alternative Fuel Economy Combined     float64
# Conventional Fuel Economy City        float64
# Conventional Fuel Economy Highway     float64
# Conventional Fuel Economy Combined    float64
# Transmission Type                      object
# Engine Type                            object
# Engine Size                            object
# Engine Cylinder Count                 float64
# Engine Description                     object
# Manufacturer                           object
# Manufacturer URL                       object
# ...

# %% [markdown]
# ***Aqui hay datos nulos, hay que verificar y eliminar, hay columnas que podemos eliminar y otras que podemos hacerle dummies***

# %%
TaxiZoneLookup=pd.read_csv('Datasets/taxi_zone_lookup.csv')

# %%
TaxiZoneLookup.isna().sum()
# Out:
# LocationID      0
# Borough         0
# Zone            1
# service_zone    2
# dtype: int64

# %%
TaxiZoneLookup.describe()
# Out:
#        LocationID
# count  265.000000
# mean   133.000000
# std     76.643112
# min      1.000000
# 25%     67.000000
# 50%    133.000000
# 75%    199.000000
# max    265.000000

# %%
TaxiZoneLookup.dtypes
# Out:
# LocationID       int64
# Borough         object
# Zone            object
# service_zone    object
# dtype: object

# %% [markdown]
# ***Aqui hay datos nulos, hay que verificar y eliminar, hay columnas que podemos eliminar y otras que podemos hacerle dummies***

# %%
VehicleFuelEconomyData=pd.read_csv('Datasets/VehicleFuelEconomyData.csv')
# Out:
# /tmp/ipykernel_8264/3156014710.py:1: DtypeWarning: Columns (73,75) have mixed types. Specify dtype option on import or set low_memory=False.
#   VehicleFuelEconomyData=pd.read_csv('Datasets/VehicleFuelEconomyData.csv')

# %%
VehicleFuelEconomyData.isna().sum()
# Out:
# Year                0
# Manufacturer        0
# Model              10
# barrels08          17
# barrelsA08         17
#                 ...
# modifiedOn       2016
# startStop       31829
# phevCity         2016
# phevHwy          2016
# phevComb         2016
# Length: 82, dtype: int64

# %%
VehicleFuelEconomyData.describe()
# Out:
#                Year     barrels08    barrelsA08     charge240        city08  \
# count  46186.000000  46169.000000  46169.000000  46169.000000  46169.000000
# mean    2003.733079     15.306719      0.166865      0.114687     19.167493
# std       12.252017      4.343434      0.869974      1.012054     10.448985
# min     1984.000000      0.047081      0.000000      0.000000      6.000000
# 25%     1992.000000     12.935217      0.000000      0.000000     15.000000
# 50%     2005.000000     14.875500      0.000000      0.000000     18.000000
# 75%     2015.000000     17.500588      0.000000      0.000000     21.000000
# max     2024.000000     42.501429     16.000000     19.000000    153.000000
#
#             city08U       cityA08      cityA08U        cityCD         cityE  \
# count  46169.000000  46169.000000  46169.000000  46169.000000  46169.000000
# mean       7.965150      0.843618      0.701921      0.000238      0.701618
# ...

# %%
VehicleFuelEconomyData.dtypes
# Out:
# Year              int64
# Manufacturer     object
# Model            object
# barrels08       float64
# barrelsA08      float64
#                  ...
# modifiedOn       object
# startStop        object
# phevCity        float64
# phevHwy         float64
# phevComb        float64
# Length: 82, dtype: object

# %%
VehicleFuelEconomyData
# Out:
#        Year Manufacturer                          Model  barrels08  \
# 0      2017          BMW                       M6 Coupe  17.500588
# 1      2017          BMW                   X3 sDrive28i  12.396250
# 2      2016     Infiniti                 Q50S Red Sport  13.523182
# 3      2017         MINI  John Cooper Works Convertible  11.018889
# 4      2017          Kia                      Sedona SX  14.167143
# ...     ...          ...                            ...        ...
# 46181  1993     Plymouth                Sundance/Duster  12.935217
# 46182  1993      Pontiac                       Grand Am  14.167143
# 46183  1993         Saab                            900  14.167143
# 46184  1993       Subaru                         Legacy  13.523182
# 46185  1993       Subaru                     Legacy AWD  14.167143
#
#        barrelsA08  charge240  city08  city08U  cityA08  cityA08U  ...  \
# 0             0.0        0.0    15.0     14.0      0.0       0.0  ...
# ...

# %% [markdown]
# ***Aqui hay datos nulos, hay que verificar y eliminar, hay columnas que podemos eliminar y otras que podemos
# hacerle dummies. Ademas estan desordenados, hay que ordenarlos, son datos interesantes, pero no los entiendo***

# %%
yellowTrip2023_01=pd.read_parquet('yellow_tripdata_2023-01.parquet')

# %%
yellowTrip2023_01.isna().sum()
# Out:
# VendorID                     0
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# passenger_count          71743
# trip_distance                0
# RatecodeID               71743
# store_and_fwd_flag       71743
# PULocationID                 0
# DOLocationID                 0
# payment_type                 0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# improvement_surcharge        0
# total_amount                 0
# congestion_surcharge     71743
# airport_fee              71743
# dtype: int64

# %%
yellowTrip2023_01.describe()
# Out:
#            VendorID  passenger_count  trip_distance    RatecodeID  \
# count  3.066766e+06     2.995023e+06   3.066766e+06  2.995023e+06
# mean   1.730215e+00     1.362532e+00   3.847342e+00  1.497440e+00
# std    4.438480e-01     8.961200e-01   2.495838e+02  6.474767e+00
# min    1.000000e+00     0.000000e+00   0.000000e+00  1.000000e+00
# 25%    1.000000e+00     1.000000e+00   1.060000e+00  1.000000e+00
# 50%    2.000000e+00     1.000000e+00   1.800000e+00  1.000000e+00
# 75%    2.000000e+00     1.000000e+00   3.330000e+00  1.000000e+00
# max    2.000000e+00     9.000000e+00   2.589281e+05  9.900000e+01
#
#        PULocationID  DOLocationID  payment_type   fare_amount         extra  \
# count  3.066766e+06  3.066766e+06  3.066766e+06  3.066766e+06  3.066766e+06
# mean   1.663980e+02  1.643926e+02  1.194483e+00  1.836707e+01  1.537842e+00
# std    6.424413e+01  6.994368e+01  5.294762e-01  1.780782e+01  1.789592e+00
# ...

# %%
yellowTrip2023_01.dtypes
# Out:
# VendorID                          int64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                      int64
# DOLocationID                      int64
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# airport_fee                     float64
# dtype: object

# %%
yellowTrip2023_01.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1         2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2         2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3         1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4         2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.97         1.0                  N           161           141
# 1           1.10         1.0                  N            43           237
# 2           2.51         1.0                  N            48           238
# 3           1.90         1.0                  N           138             7
# 4           1.43         1.0                  N           107            79
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %% [markdown]
# ***Aqui hay datos nulos, hay que verificar y eliminar, hay columnas que podemos eliminar y otras que podemos hacerle dummies***

# %%
yellowTrip2023_03=pd.read_parquet('yellow_tripdata_2023-03.parquet')

# %%
yellowTrip2023_03.isna().sum()
# Out:
# VendorID                     0
# tpep_pickup_datetime         0
# tpep_dropoff_datetime        0
# passenger_count          87619
# trip_distance                0
# RatecodeID               87619
# store_and_fwd_flag       87619
# PULocationID                 0
# DOLocationID                 0
# payment_type                 0
# fare_amount                  0
# extra                        0
# mta_tax                      0
# tip_amount                   0
# tolls_amount                 0
# improvement_surcharge        0
# total_amount                 0
# congestion_surcharge     87619
# Airport_fee              87619
# dtype: int64

# %%
yellowTrip2023_03.describe()
# Out:
#            VendorID  passenger_count  trip_distance    RatecodeID  \
# count  3.403766e+06     3.316147e+06   3.403766e+06  3.316147e+06
# mean   1.725320e+00     1.351417e+00   3.903871e+00  1.623961e+00
# std    4.588677e-01     8.861919e-01   1.916866e+02  7.358691e+00
# min    1.000000e+00     0.000000e+00   0.000000e+00  1.000000e+00
# 25%    1.000000e+00     1.000000e+00   1.050000e+00  1.000000e+00
# 50%    2.000000e+00     1.000000e+00   1.790000e+00  1.000000e+00
# 75%    2.000000e+00     1.000000e+00   3.380000e+00  1.000000e+00
# max    6.000000e+00     9.000000e+00   2.169870e+05  9.900000e+01
#
#        PULocationID  DOLocationID  payment_type   fare_amount         extra  \
# count  3.403766e+06  3.403766e+06  3.403766e+06  3.403766e+06  3.403766e+06
# mean   1.654540e+02  1.641003e+02  1.187310e+00  1.890845e+01  1.629128e+00
# std    6.373958e+01  6.967282e+01  5.334025e-01  1.825637e+01  1.842778e+00
# ...

# %%
yellowTrip2023_03.dtypes
# Out:
# VendorID                          int32
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                      int32
# DOLocationID                      int32
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# Airport_fee                     float64
# dtype: object

# %%
yellowTrip2023_03.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2023-03-01 00:06:43   2023-03-01 00:16:43              1.0
# 1         2  2023-03-01 00:08:25   2023-03-01 00:39:30              2.0
# 2         1  2023-03-01 00:15:04   2023-03-01 00:29:26              0.0
# 3         1  2023-03-01 00:49:37   2023-03-01 01:01:05              1.0
# 4         2  2023-03-01 00:08:04   2023-03-01 00:11:06              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.00         1.0                  N           238            42
# 1          12.40         1.0                  N           138           231
# 2           3.30         1.0                  N           140           186
# 3           2.90         1.0                  N           140            43
# 4           1.23         1.0                  N            79           137
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %% [markdown]
# ***Aqui hay datos nulos, hay que verificar y eliminar, hay columnas que podemos eliminar y otras que podemos hacerle dummies***
